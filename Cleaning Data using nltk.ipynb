# %%
import re

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
file1='This is my learning experiment with Natural Language Processing.'

# %%
#tokenize the words
tokens=word_tokenize(file1)

# %%
print(tokens)
# Out:
# ['This', 'is', 'my', 'learning', 'experiment', 'with', 'Natural', 'Language', 'Processing', '.']

# %%
words=[len(word) for word in tokens]

# %%
print(words)
# Out:
# [4, 2, 2, 8, 10, 4, 7, 8, 10, 1]

# %%
#the number of words 
print(len(words))
# Out:
# 10

# %%
re_punc=r"[\.]"

# %%
words = re.sub(re_punc,' ', file1)

# %%
print(words)
# Out:
# This is my learning experiment with Natural Language Processing

# %%
print(tokens[:10])
import string
# Out:
# ['one', 'morning', ',', 'when', 'gregor', 'samsa', 'woke', 'from', 'troubled', 'dreams']

# %%
#convert text to lower case
tokens=[w.lower() for w in tokens]
#prepare the regex for character filter
re_punc=re.compile('[%s]' %re.escape(string.punctuation))

# %%
# remove punctuation
#stripped =[re_punc.sub('',w)for w in tokens]
stripped =[re.sub(re_punc ,'',w) for w in tokens]
# now let me remove the remaining tokens that are not alphanumeric
words= [word for word in stripped if word.isalpha()]
print(words)
# Out:
# ['one', 'morning', 'when', 'gregor', 'samsa', 'woke', 'from', 'troubled', 'dreams', 'he', 'found', 'himself', 'transformed', 'in', 'his', 'bed', 'into', 'a', 'horrible', 'vermin', 'he', 'lay', 'on', 'his', 'armourlike', 'back', 'and', 'if', 'he', 'lifted', 'his', 'head', 'a', 'little', 'he', 'could', 'see', 'his', 'brown', 'belly', 'slightly', 'domed', 'and', 'divided', 'by', 'arches', 'into', 'stiff', 'sections', 'the', 'bedding', 'was', 'hardly', 'able', 'to', 'cover', 'it', 'and', 'seemed', 'ready', 'to', 'slide', 'off', 'any', 'moment', 'his', 'many', 'legs', 'pitifully', 'thin', 'compared', 'with', 'the', 'size', 'of', 'the', 'rest', 'of', 'him', 'waved', 'about', 'helplessly', 'as', 'he', 'looked', 'what', 's', 'happened', 'to', 'me', 'he', 'thought', 'it', 'was', 'nt', 'a', 'dream', 'his', 'room', 'a', 'proper', 'human', 'room', 'although', 'a', 'little', 'too', 'small', 'lay', 'peacefully', 'between', 'its', 'four', 'familiar', 'walls', 'a', 'collection', 'of', 'textile', 'sa
# ...

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# filter out the stop words
stop_words=set(stopwords.words('english'))
words=[w for w in words if not w in stop_words]
#print(words)
#stemming the words
porter =PorterStemmer()
stemmed=[porter.stem(word) for word in words]
print(stemmed)
# Out:
# ['one', 'morn', 'gregor', 'samsa', 'woke', 'troubl', 'dream', 'found', 'transform', 'bed', 'horribl', 'vermin', 'lay', 'armourlik', 'back', 'lift', 'head', 'littl', 'could', 'see', 'brown', 'belli', 'slightli', 'dome', 'divid', 'arch', 'stiff', 'section', 'bed', 'hardli', 'abl', 'cover', 'seem', 'readi', 'slide', 'moment', 'mani', 'leg', 'piti', 'thin', 'compar', 'size', 'rest', 'wave', 'helplessli', 'look', 'happen', 'thought', 'nt', 'dream', 'room', 'proper', 'human', 'room', 'although', 'littl', 'small', 'lay', 'peac', 'four', 'familiar', 'wall', 'collect', 'textil', 'sampl', 'lay', 'spread', 'tabl', 'samsa', 'travel', 'salesman', 'hung', 'pictur', 'recent', 'cut', 'illustr', 'magazin', 'hous', 'nice', 'gild', 'frame', 'show', 'ladi', 'fit', 'fur', 'hat', 'fur', 'boa', 'sat', 'upright', 'rais', 'heavi', 'fur', 'muff', 'cover', 'whole', 'lower', 'arm', 'toward', 'viewer', 'gregor', 'turn', 'look', 'window', 'dull', 'weather', 'drop', 'rain', 'could', 'heard', 'hit', 'pane', 'made',
# ...

# %%
#find all digits in the above text using regex
digits= r"\d+"
print(re.findall(digits , text))
# Out:
# []

# %%
# Write a pattern to match sentence endings: sentence_endings
sentence_endings = r"[.?!]"
temporary_text=(re.findall(sentence_endings , text))
temporary_text[:10]
# Out:
# ['.', '.', '.', '.', '?', '.', '.', '.', '.', '.']

# %%
#find all capital words and print them on the screen
capital_words= r"[A-Z]\w+"
print(re.findall(capital_words , text))
# Out:
# ['One', 'Gregor', 'Samsa', 'He', 'The', 'His', 'What', 'It', 'His', 'Samsa', 'It', 'Gregor', 'Drops', 'How', 'However', 'He', 'Oh', 'God', 'Travelling', 'Doing', 'It', 'Hell', 'He', 'He', 'Getting', 'You', 'Other', 'For', 'But', 'If', 'He', 'And', 'Well', 'That', 'First', 'And', 'God', 'Heaven', 'It', 'Had', 'He', 'Yes', 'True', 'What', 'The', 'And', 'Gregor', 'The', 'What', 'But', 'Gregor', 'His', 'And', 'Gregor', 'He', 'There', 'Gregor', 'Didn', 'That', 'Gregor', 'As', 'Gregor', 'Yes', 'The', 'Gregor', 'But', 'Gregor', 'Gregor', 'Gregor', 'And', 'Gregor', 'Gregor', 'At', 'Gregor', 'Aren', 'Do', 'Gregor', 'His', 'Gregor', 'Gregor', 'The', 'Only', 'He', 'He', 'It', 'But', 'He', 'If', 'This', 'Gregor', 'The', 'So', 'This', 'But', 'And', 'It', 'He', 'At', 'At', 'Seven', 'And', 'But', 'Before', 'And', 'And', 'If', 'His', 'His', 'But', 'When', 'Gregor', 'Two', 'Should', 'Despite', 'After', 'The', 'Then', 'That', 'For', 'They', 'Gregor', 'But', 'Gregor', 'Why', 'Gregor', 'Were', 'Was', 'A
# ...

# %%
# print the length of the words
import matplotlib.pyplot as plt
import nltk

# %%
from nltk.tokenize import word_tokenize
words=word_tokenize("This is my Natural Language Processing Chapter , I am enjoying doing what I am doing.")
word_len= [len(word) for word in words ]
print(word_len)
print(len(word_len))
plt.plot(word_len)
plt.show()
# Out:
# [4, 2, 2, 7, 8, 10, 7, 1, 1, 2, 8, 5, 4, 1, 2, 5, 1]
# 17

# %%
plt.hist(word_len ,bins=17)
plt.xlabel("The words relative position")
plt.ylabel("number of character per word")
plt.show()
