# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/anirbanghoshsbi/Cleaning-text-Document/blob/master/name_classifier_using_sklearn.ipynb)

# %%
#import libraries
import nltk
from nltk.corpus import names
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# True

# %%
from sklearn.model_selection import train_test_split

# %%
def feature_selection(name):
  return { 'last_name' : name[-1]}

# %%
#create a dataset
boys_names = names.words('male.txt')

# %%
girls_names = names.words('female.txt')

# %%
boys_dataset =[(feature_selection(name),'boy') for name in boys_names]

# %%
girls_dataset =[(feature_selection(name) , 'girl') for name in girls_names]

# %%
data = boys_dataset + girls_dataset

# %%
X,y = list(zip(*data))

# %%
import numpy as np
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size =0.25 , shuffle= True)
#y_train= np.asarray(y_train)

# %%
print(X_train)
# Out:
# [{'last_name': 'a'}, {'last_name': 'a'}, {'last_name': 'd'}, {'last_name': 'a'}, {'last_name': 'e'}, {'last_name': 'n'}, {'last_name': 'r'}, {'last_name': 'y'}, {'last_name': 'o'}, {'last_name': 'n'}, {'last_name': 'e'}, {'last_name': 'n'}, {'last_name': 'e'}, {'last_name': 'y'}, {'last_name': 'a'}, {'last_name': 'g'}, {'last_name': 'y'}, {'last_name': 'e'}, {'last_name': 't'}, {'last_name': 'y'}, {'last_name': 'e'}, {'last_name': 'a'}, {'last_name': 'a'}, {'last_name': 'y'}, {'last_name': 'n'}, {'last_name': 'r'}, {'last_name': 't'}, {'last_name': 'x'}, {'last_name': 'a'}, {'last_name': 'b'}, {'last_name': 'e'}, {'last_name': 'a'}, {'last_name': 'a'}, {'last_name': 'e'}, {'last_name': 'r'}, {'last_name': 'f'}, {'last_name': 'a'}, {'last_name': 'y'}, {'last_name': 'e'}, {'last_name': 'e'}, {'last_name': 'n'}, {'last_name': 'n'}, {'last_name': 'y'}, {'last_name': 'm'}, {'last_name': 'e'}, {'last_name': 'e'}, {'last_name': 's'}, {'last_name': 'a'}, {'last_name': 'r'}, {'last_name': 'e'
# ...

# %%
print(y_train)
# Out:
# ['girl', 'girl', 'boy', 'girl', 'girl', 'boy', 'boy', 'boy', 'girl', 'boy', 'girl', 'girl', 'girl', 'boy', 'girl', 'boy', 'girl', 'girl', 'boy', 'boy', 'boy', 'girl', 'girl', 'girl', 'girl', 'boy', 'boy', 'girl', 'girl', 'boy', 'girl', 'girl', 'girl', 'girl', 'boy', 'boy', 'girl', 'girl', 'boy', 'girl', 'girl', 'girl', 'girl', 'boy', 'girl', 'girl', 'boy', 'girl', 'boy', 'girl', 'boy', 'girl', 'girl', 'girl', 'girl', 'boy', 'girl', 'girl', 'boy', 'boy', 'girl', 'girl', 'girl', 'boy', 'girl', 'boy', 'boy', 'girl', 'boy', 'boy', 'boy', 'boy', 'boy', 'girl', 'boy', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'boy', 'boy', 'girl', 'boy', 'girl', 'girl', 'boy', 'girl', 'girl', 'girl', 'boy', 'girl', 'girl', 'boy', 'boy', 'boy', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'boy', 'boy', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'girl', 'boy', 'boy', 'girl', 'girl', 'boy', 'girl', 'boy', 'girl', 'boy', 'boy', 'girl', 'girl', 'boy', 'boy', 'boy', 
# ...

# %% [markdown]
# Most common methods used with Sk-learn Model
# 1. Transformations
#
#
# 2.Predictions
#
#
# methods
#
#
# fit: used for training the sklearn component
#
#
# transform: used to convert the data format
#
#
# predict:used for classifying the datapoint
#
#
# score: Evaluate the accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
dict_vector = DictVectorizer()
name_classifier = DecisionTreeClassifier()

# %%
# fit the data
dict_vector.fit(X_train)
# Out:
# DictVectorizer(dtype=<class 'numpy.float64'>, separator='=', sort=True,
#         sparse=True)

# %%
# Classify the data
X_train_vectorized = dict_vector.transform(X_train)

# %%
name_classifier.fit(X_train_vectorized , y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
X_test_vectorizer = dict_vector.transform(X_test)

# %%
names = ['lara','anirban','sunday','rabbit','sakhi','sakha','george']
transformed = dict_vector.transform([feature_selection(name) for name in names])
print(name_classifier.predict(transformed))
# Out:
# ['girl' 'boy' 'girl' 'boy' 'girl' 'girl' 'girl']
